# %%
# !pip install youtube-transcript-api
# Out:
# Requirement already satisfied: youtube-transcript-api in /home/prashant/genai/lib/python3.13/site-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/prashant/genai/lib/python3.13/site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /home/prashant/genai/lib/python3.13/site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/prashant/genai/lib/python3.13/site-packages (from requests->youtube-transcript-api) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/prashant/genai/lib/python3.13/site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/prashant/genai/lib/python3.13/site-packages (from requests->youtube-transcript-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prashant/genai/lib/python3.13/site-packages (from requests->youtube-transcript-api) (2026.2.25)

# %%
from langchain_community.document_loaders import YoutubeLoader

# 1. Initialize the loader
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=FuqNluMTIR8", 
    add_video_info=False
)

# 2. Load the data into a list of Documents
docs = loader.load()

# 3. Access the content
print(docs[0].page_content[:500])  # The transcript text
# print(docs[0].metadata)
# Out:
# hey there my name is Demitri and in this video
# we're going to dive into the three simple hacks   that you can use to get a YouTube video transcript
# and summarize it and what I often struggle with   is the fact that there's a lot of really great
# information in YouTube videos but unfortunately it   can be kind of difficult to wrap your head around
# it when it's all verbal and visual and sometimes   you just want to have different components written
# out so that you can actually give advice to o
